# %%
import pandas as pd

# %%
scope = pd.read_csv("/home/yacan/Programs/projects/non-linear-distortion/scripts/scope_91.csv")[1:].astype('float')
scope.head()
# Out:
#    x-axis         1         2
# 1 -0.0996  4.922744 -0.263819
# 2 -0.0995  4.970482 -0.238693
# 3 -0.0994  5.003146  0.000000
# 4 -0.0993  4.995608  0.000000
# 5 -0.0992  4.950382 -0.402010

# %%
scope.plot()
# Out:
# <Axes: >

# %%
scope['1'].mean()
# Out:
# np.float64(4.963266342499999)
